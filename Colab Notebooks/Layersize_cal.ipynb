# %%
import numpy as np

# %%
Stride = [2,2,2,2,2] #@param
kernelsize = [5,5,3,3,3] #@param
padding = [0,0,0,0,0,0]
image_input = 224 #@param

for i in range(len(Stride)):
  image_input = np.floor((image_input - kernelsize[i]+ 2*padding[i])/Stride[i]) + 1
  #image_input = (image_input - kernelsize[i]+ 2*padding[i])/Stride[i] + 1
  print(image_input)
# Out:
# 110.0
# 53.0
# 26.0
# 12.0
# 5.0
