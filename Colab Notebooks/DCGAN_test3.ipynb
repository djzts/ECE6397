# %%
from __future__ import print_function, division

#from keras.datasets import mnist
from keras.layers import Input, Dense, Reshape, Flatten, Dropout
from keras.layers import BatchNormalization, Activation, ZeroPadding2D
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.convolutional import UpSampling2D, Conv2D
from keras.models import Sequential, Model
from keras.optimizers import Adam
import matplotlib.pyplot as plt
from tqdm import notebook
import os
import sys
import numpy as np

# %%
def load_data():
  #data_x_p1 = np.load("/content/drive/MyDrive/UHCourse/ECE6397/mldata/Data_x_Bacteria.npy")
  #data_x_p2 = np.load("/content/drive/MyDrive/UHCourse/ECE6397/mldata/Data_x_Normal.npy")
  data_x_p3 = np.load("/content/drive/MyDrive/UHCourse/ECE6397/mldata/Data_x_Virus.npy")
  #data_x_p4 = np.load("/content/drive/MyDrive/UHCourse/ECE6397/mldata/Data_x_Covid.npy")
  #X_Train = np.concatenate((data_x_p1,data_x_p2,data_x_p3,data_x_p4),axis = 0)

  #data_y_p1 = np.load("/content/drive/MyDrive/UHCourse/ECE6397/mldata/Data_y_Bacteria.npy")
  #data_y_p2 = np.load("/content/drive/MyDrive/UHCourse/ECE6397/mldata/Data_y_Normal.npy")
  data_y_p3 = np.load("/content/drive/MyDrive/UHCourse/ECE6397/mldata/Data_y_Virus.npy")
  #data_y_p4 = np.load("/content/drive/MyDrive/UHCourse/ECE6397/mldata/Data_y_Covid.npy")
  #y_Train = np.concatenate((data_y_p1,data_y_p2,data_y_p3,data_y_p4),axis = 0)

  #return X_Train, y_Train
  return data_x_p3, data_y_p3

# %%
class DCGAN():
    def __init__(self):
        # Input shape
        self.img_rows = 224  #@param  # 图像的高
        self.img_cols = 224  #@param  # 图像的宽
        self.channels = 3    #@param  # 彩色图像
        self.img_shape = (self.img_rows, self.img_cols, self.channels)
        self.latent_dim = 100 #@param  #输入100维度输入
        # 设置学习率为0.0001
        optimizer = Adam(0.0002, 0.5)

        # Build and compile the discriminator
        self.discriminator = self.build_discriminator()
        self.discriminator.compile(loss='binary_crossentropy',
            optimizer=optimizer,
            metrics=['accuracy'])

        # Build the generator
        self.generator = self.build_generator()

        # The generator takes noise as input and generates imgs
        z = Input(shape=(self.latent_dim,))
        img = self.generator(z)

        # For the combined model we will only train the generator
        self.discriminator.trainable = False

        # The discriminator takes generated images as input and determines validity
        valid = self.discriminator(img)

        # The combined model  (stacked generator and discriminator)
        # Trains the generator to fool the discriminator
        self.combined = Model(z, valid)
        self.combined.compile(loss='binary_crossentropy', optimizer=optimizer)
    def build_generator(self):
        # 模型到深度及设置
        depths = [1024 , 512 , 256 , 128, 64, 32,3]  #@param
        model = Sequential()
        model.add(Dense(1000 * 7 * 7, activation="relu", input_dim=self.latent_dim)) 
        model.add(Reshape((7, 7, 1000))) 
        #（7，7，1000）
        model.add(UpSampling2D())
        model.add(Conv2D(512, kernel_size=3, padding="same"))
        model.add(BatchNormalization(momentum=0.8))
        model.add(Activation("relu"))
        #（14，14，512）
        model.add(UpSampling2D()) 
        model.add(Conv2D(256, kernel_size=3, padding="same"))
        model.add(BatchNormalization(momentum=0.8))
        model.add(Activation("relu"))
        #（28，28，256）
        model.add(UpSampling2D()) 
        model.add(Conv2D(128, kernel_size=3, padding="same"))
        model.add(BatchNormalization(momentum=0.8))
        model.add(Activation("relu"))
        #（56，56，128）
        model.add(UpSampling2D()) 
        model.add(Conv2D(64, kernel_size=3, padding="same"))
        model.add(BatchNormalization(momentum=0.8))
        model.add(Activation("relu"))
        #（112，112，64）
        model.add(UpSampling2D())        
        model.add(Conv2D(32, kernel_size=3, padding="same"))
        model.add(BatchNormalization(momentum=0.8))
        model.add(Activation("relu"))
        model.add(Conv2D(self.channels, kernel_size=3, padding="same"))
        model.add(Activation("tanh"))
        #（224，224,3）
        model.summary()
        noise = Input(shape=(self.latent_dim,))
        img = model(noise)
        return Model(noise, img)
    def build_discriminator(self):
        Kernel_size = [7,4,3,3,3,3] #@param
        Stride = [2,2,2,2,2,2] #@param
        dropout = 0.13 #@param
        _momentum = 0.87 #@param
        _alpha = 0.1 #@param
        model = Sequential()
        #0
        model.add(Conv2D(32, kernel_size = Kernel_size[0], strides = Stride[0], input_shape=self.img_shape, padding="same"))
        model.add(LeakyReLU(alpha=_alpha))
        model.add(Dropout(dropout))
        #1
        model.add(Conv2D(64, kernel_size= Kernel_size[1], strides = Stride[1], padding="same"))
        #model.add(ZeroPadding2D(padding=((0,1),(0,1))))
        model.add(BatchNormalization(momentum=_momentum))
        model.add(LeakyReLU(alpha=_alpha))
        model.add(Dropout(dropout))
        #2
        model.add(Conv2D(128, kernel_size= Kernel_size[2], strides = Stride[2], padding="same"))
        model.add(BatchNormalization(momentum=_momentum))
        model.add(LeakyReLU(alpha=_alpha))
        model.add(Dropout(dropout))
        #3
        model.add(Conv2D(256, kernel_size=Kernel_size[3], strides= Stride[3], padding="same"))
        model.add(BatchNormalization(momentum=_momentum))
        model.add(LeakyReLU(alpha=_alpha))
        model.add(Dropout(dropout))
        #4
        model.add(Conv2D(512, kernel_size= Kernel_size[4], strides= Stride[4], padding="same"))
        model.add(BatchNormalization(momentum=_momentum))
        model.add(LeakyReLU(alpha=_alpha))
        model.add(Dropout(dropout))    
        #5
        model.add(Conv2D(1024, kernel_size= Kernel_size[5], strides= Stride[5], padding="same"))
        model.add(BatchNormalization(momentum=_momentum))
        model.add(LeakyReLU(alpha=_alpha))
        model.add(Dropout(dropout))                 
        #6
        model.add(Flatten())
        model.add(Dense(1, activation='sigmoid'))
        model.summary()
        img = Input(shape=self.img_shape)
        validity = model(img)
        return Model(img, validity)
    def train(self, epochs, batch_size=128, save_interval=50):
        # Load the dataset
        X_train,y1 = load_data()
        pic_path = os.getcwd()+'/batch_size_'+str(batch_size)+'_save_interval'+str(save_interval)
        os.mkdir(pic_path)
        valid = np.ones((batch_size, 1))
        fake = np.zeros((batch_size, 1))
        for epoch in notebook.tqdm(range(epochs)):
            # ---------------------
            #  Train Discriminator
            # Select a random half of images
            idx = np.random.randint(0, X_train.shape[0], batch_size)
            imgs = X_train[idx]
            # Sample noise and generate a batch of new images
            noise = np.random.normal(0, 1, (batch_size, self.latent_dim))
            gen_imgs = self.generator.predict(noise)
            # Train the discriminator (real classified as ones and generated as zeros)
            d_loss_real = self.discriminator.train_on_batch(imgs, valid)
            d_loss_fake = self.discriminator.train_on_batch(gen_imgs, fake)
            d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
            # ---------------------
            #  Train Generator
            # ---------------------
            # Train the generator (wants discriminator to mistake images as real)
            g_loss = self.combined.train_on_batch(noise, valid)
            # Plot the progress
            # If at save interval => save generated image samples
            if epoch % save_interval == 0:

                self.save_imgs(epoch,pic_path)
                print ("%d [D loss: %f, acc.: %.2f%%] [G loss: %f]" % (epoch, d_loss[0], 100*d_loss[1], g_loss))
    def save_imgs(self, epoch,pic_path):
        r, c = 2, 2 #@param
        noise = np.random.normal(0, 1, (r * c, self.latent_dim))
        gen_imgs = self.generator.predict(noise)
        # Rescale images 0 - 1
        gen_imgs = 0.5 * gen_imgs + 0.5
        fig, axs = plt.subplots(r, c)
        cnt = 0
        for i in range(r):
            for j in range(c):
                axs[i,j].imshow(gen_imgs[cnt, :,:,:])
                axs[i,j].axis('off')
                cnt += 1
        fig.savefig(pic_path+"/img_%d.png" % epoch)
        plt.close()

# %%
dcgan = DCGAN()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_36 (Conv2D)           (None, 112, 112, 32)      4736
# _________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)   (None, 112, 112, 32)      0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 112, 112, 32)      0
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 56, 56, 64)        32832
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 56, 56, 64)        256
# _________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)   (None, 56, 56, 64)        0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 28, 28, 128)       73856
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 28, 28, 128)       512
# _________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)   (None, 28, 28, 128)       0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 14, 14, 256)       295168
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 14, 14, 256)       1024
# _________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)   (None, 14, 14, 256)       0
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 7, 7, 512)         1180160
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 7, 7, 512)         2048
# _________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)   (None, 7, 7, 512)         0
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 7, 7, 512)         0
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 4, 4, 1024)        4719616
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 4, 4, 1024)        4096
# _________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)   (None, 4, 4, 1024)        0
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 4, 4, 1024)        0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 16384)             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 16385
# =================================================================
# Total params: 6,330,689
# Trainable params: 6,326,721
# Non-trainable params: 3,968
# _________________________________________________________________
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 49000)             4949000
# _________________________________________________________________
# reshape_3 (Reshape)          (None, 7, 7, 1000)        0
# _________________________________________________________________
# up_sampling2d_15 (UpSampling (None, 14, 14, 1000)      0
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 14, 14, 512)       4608512
# _________________________________________________________________
# batch_normalization_35 (Batc (None, 14, 14, 512)       2048
# _________________________________________________________________
# activation_18 (Activation)   (None, 14, 14, 512)       0
# _________________________________________________________________
# up_sampling2d_16 (UpSampling (None, 28, 28, 512)       0
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 28, 28, 256)       1179904
# _________________________________________________________________
# batch_normalization_36 (Batc (None, 28, 28, 256)       1024
# _________________________________________________________________
# activation_19 (Activation)   (None, 28, 28, 256)       0
# _________________________________________________________________
# up_sampling2d_17 (UpSampling (None, 56, 56, 256)       0
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 56, 56, 128)       295040
# _________________________________________________________________
# batch_normalization_37 (Batc (None, 56, 56, 128)       512
# _________________________________________________________________
# activation_20 (Activation)   (None, 56, 56, 128)       0
# _________________________________________________________________
# up_sampling2d_18 (UpSampling (None, 112, 112, 128)     0
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 112, 112, 64)      73792
# _________________________________________________________________
# batch_normalization_38 (Batc (None, 112, 112, 64)      256
# _________________________________________________________________
# activation_21 (Activation)   (None, 112, 112, 64)      0
# _________________________________________________________________
# up_sampling2d_19 (UpSampling (None, 224, 224, 64)      0
# _________________________________________________________________
# conv2d_46 (Conv2D)           (None, 224, 224, 32)      18464
# _________________________________________________________________
# batch_normalization_39 (Batc (None, 224, 224, 32)      128
# _________________________________________________________________
# activation_22 (Activation)   (None, 224, 224, 32)      0
# _________________________________________________________________
# conv2d_47 (Conv2D)           (None, 224, 224, 3)       867
# _________________________________________________________________
# activation_23 (Activation)   (None, 224, 224, 3)       0
# =================================================================
# Total params: 11,129,547
# Trainable params: 11,127,563
# Non-trainable params: 1,984
# _________________________________________________________________

# %%
dcgan.train(epochs=10000, batch_size=130, save_interval=100)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10000.0), HTML(value='')))
# 0 [D loss: 3.617325, acc.: 34.62%] [G loss: 0.636498]
# 100 [D loss: 0.013257, acc.: 100.00%] [G loss: 0.658684]
# 200 [D loss: 0.000381, acc.: 100.00%] [G loss: 0.004391]
# 300 [D loss: 0.000240, acc.: 100.00%] [G loss: 0.002398]
# 400 [D loss: 0.000107, acc.: 100.00%] [G loss: 0.001316]
# 500 [D loss: 0.000055, acc.: 100.00%] [G loss: 0.000868]
# 600 [D loss: 0.000026, acc.: 100.00%] [G loss: 0.000754]
# 700 [D loss: 0.000036, acc.: 100.00%] [G loss: 0.000678]
# 800 [D loss: 0.000015, acc.: 100.00%] [G loss: 0.000354]
# 900 [D loss: 0.000022, acc.: 100.00%] [G loss: 0.000466]
# 1000 [D loss: 0.000016, acc.: 100.00%] [G loss: 0.000358]
# 1100 [D loss: 0.000011, acc.: 100.00%] [G loss: 0.000314]
# 1200 [D loss: 0.000013, acc.: 100.00%] [G loss: 0.000281]
# 1300 [D loss: 0.000011, acc.: 100.00%] [G loss: 0.000280]
# 1400 [D loss: 0.000009, acc.: 100.00%] [G loss: 0.000208]
# 1500 [D loss: 0.000007, acc.: 100.00%] [G loss: 0.000166]
# 1600 [D loss: 0.000009, acc.: 100.00%] [G loss: 0.000201]
# 1700 [D loss: 0.000008, acc.: 100.00%] [G loss: 0.000155]
# 1800 [D loss: 0.000003, acc.: 100.00%] [G loss: 0.000137]
# 1900 [D loss: 0.000003, acc.: 100.00%] [G loss: 0.000127]
# 2000 [D loss: 0.000007, acc.: 100.00%] [G loss: 0.000119]
# 2100 [D loss: 0.000002, acc.: 100.00%] [G loss: 0.000117]
# 2200 [D loss: 0.000004, acc.: 100.00%] [G loss: 0.000120]
# 2300 [D loss: 0.000005, acc.: 100.00%] [G loss: 0.000108]
# 2400 [D loss: 0.000001, acc.: 100.00%] [G loss: 0.000117]
# 2500 [D loss: 0.000004, acc.: 100.00%] [G loss: 0.000106]
# 2600 [D loss: 0.000002, acc.: 100.00%] [G loss: 0.000110]
# 2700 [D loss: 0.000002, acc.: 100.00%] [G loss: 0.000140]
# 2800 [D loss: 0.000002, acc.: 100.00%] [G loss: 0.000074]
# 2900 [D loss: 0.000002, acc.: 100.00%] [G loss: 0.000101]
# 3000 [D loss: 0.000001, acc.: 100.00%] [G loss: 0.000104]
# 3100 [D loss: 0.000002, acc.: 100.00%] [G loss: 0.000098]
# 3200 [D loss: 0.000002, acc.: 100.00%] [G loss: 0.000102]
# 3300 [D loss: 0.000001, acc.: 100.00%] [G loss: 0.000073]
# 3400 [D loss: 0.000001, acc.: 100.00%] [G loss: 0.000058]
# 3500 [D loss: 0.000001, acc.: 100.00%] [G loss: 0.000061]
# 3600 [D loss: 0.000001, acc.: 100.00%] [G loss: 0.000039]
# 3700 [D loss: 0.000001, acc.: 100.00%] [G loss: 0.000049]
# 3800 [D loss: 0.000001, acc.: 100.00%] [G loss: 0.000043]
# 3900 [D loss: 0.000001, acc.: 100.00%] [G loss: 0.000045]
# 4000 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000031]
# 4100 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000028]
# 4200 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000044]
# 4300 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000027]
# 4400 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000024]
# 4500 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000026]
# 4600 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000032]
# 4700 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000024]
# 4800 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000022]
# 4900 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000017]
# 5000 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000020]
# 5100 [D loss: 0.000001, acc.: 100.00%] [G loss: 0.000020]
# 5200 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000022]
# 5300 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000024]
# 5400 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000017]
# 5500 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000015]
# 5600 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000017]
# 5700 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000013]
# 5800 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000009]
# 5900 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000012]
# 6000 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000014]
# 6100 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000010]
# 6200 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000011]
# 6300 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000013]
# 6400 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000009]
# 6500 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000008]
# 6600 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000008]
# 6700 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000009]
# 6800 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000008]
# 6900 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000008]
# 7000 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000005]
# 7100 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000008]
# 7200 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000009]
# 7300 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000004]
# 7400 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000006]
# 7500 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000004]
# 7600 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000004]
# 7700 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000004]
# 7800 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000004]
# 7900 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000004]
# 8000 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000005]
# 8100 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000003]
# 8200 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000003]
# 8300 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000002]
# 8400 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000002]
# 8500 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000002]
# 8600 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000002]
# 8700 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000002]
# 8800 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000002]
# 8900 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000003]
# 9000 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000002]
# 9100 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000002]
# 9200 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000002]
# 9300 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000001]
# 9400 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000002]
# 9500 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000002]
# 9600 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000003]
# 9700 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000001]
# 9800 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000002]
# 9900 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000001]

# %%
|
