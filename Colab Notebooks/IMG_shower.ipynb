# %%
import matplotlib.pyplot as plt
from tqdm import notebook
import os
import sys
import numpy as np
import cv2

# %%
def load_data():
  data_x_p1 = np.load("/content/drive/MyDrive/UHCourse/ECE6397/mldata_256/Data_x_Bacteria.npy")
  #data_x_p2 = np.load("/content/drive/MyDrive/UHCourse/ECE6397/mldata/Data_x_Normal.npy")
  #data_x_p3 = np.load("/content/drive/MyDrive/UHCourse/ECE6397/mldata/Data_x_Virus.npy")
  #data_x_p4 = np.load("/content/drive/MyDrive/UHCourse/ECE6397/mldata/Data_x_Covid.npy")
  #X_Train = np.concatenate((data_x_p1,data_x_p2,data_x_p3,data_x_p4),axis = 0)

  data_y_p1 = np.load("/content/drive/MyDrive/UHCourse/ECE6397/mldata_64/Data_y_Bacteria.npy")
  #data_y_p2 = np.load("/content/drive/MyDrive/UHCourse/ECE6397/mldata/Data_y_Normal.npy")
  #data_y_p3 = np.load("/content/drive/MyDrive/UHCourse/ECE6397/mldata/Data_y_Virus.npy")
  #data_y_p4 = np.load("/content/drive/MyDrive/UHCourse/ECE6397/mldata/Data_y_Covid.npy")
  #y_Train = np.concatenate((data_y_p1,data_y_p2,data_y_p3,data_y_p4),axis = 0)

  #return X_Train, y_Train
  return data_x_p1, data_y_p1

# %%
X,y = load_data()

# %%
#plt.gray()
plt.imshow((X[0,:,:,0]+1)/2)

# %%
a = X[0,:,:,0]-X[0,:,:,1]
plt.imshow(a)

# %%
X_mean = np.mean(X[0,:,:,:],axis=-1)

# %%
plt.imshow((X_mean+1)/2)
print(X_mean.shape)
# Out:
# (28, 28)

# %%
#mimic = np.load("/content/drive/MyDrive/UHCourse/ECE6397/mlresult_28/Bacteria_BS_150_SI100/img_1600.npy")
num =  (224,100,100,900)#@param

mimic = cv2.imread("/content/drive/MyDrive/UHCourse/ECE6397/mlresult_%d/Covid_BS_%d_SI%d/img_%d.png"%num)
nn = cv2.imread("/content/drive/MyDrive/UHCourse/ECE6397/mlresult_%d/Covid_BS_%d_SI%d/img_%d.png"%num, cv2.IMREAD_GRAYSCALE)

# %%
plt.subplot(1,2,1)
plt.imshow((mimic[:,:,:],cmap=plt.get_cmap('gray'))
plt.subplot(1,2,2)
plt.imshow(nn,cmap=plt.get_cmap('gray'))

# %%
fig= plt.imshow(nn,cmap=plt.get_cmap('gray'))
plt.savefig('256_Covid')

# %%
size = 2
s  = '/content/drive/MyDrive/UHCourse/ECE6397/Data_npy_%d/Normal/'% size +"sd"

# %%
print(s)
# Out:
# /content/drive/MyDrive/UHCourse/ECE6397/Data_npy_2/Normal/sd

# %%
P = np.load("/content/drive/MyDrive/UHCourse/ECE6397/Data_npy_128/Bacteria/person1000_bacteria_2931.npy")

# %%
len(os.listdir('/content/drive/MyDrive/UHCourse/ECE6397/Data_npy_128/Bacteria/'))
# Out:
# 2780

# %%
len(os.listdir('/content/drive/MyDrive/UHCourse/ECE6397/Data_npy_56/Covid/'))
# Out:
# 4695

# %%
np.shape(P)
# Out:
# (128, 128, 3)

# %%
plt.imshow((P+1)/2)
